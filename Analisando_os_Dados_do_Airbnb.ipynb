# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielcardosods/data_science/blob/master/Analisando_os_Dados_do_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Análise de dados" height="30px" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png"></p>
#
# #### **Data Science na Prática 2.0**
# por <a href="https://github.com/gabrielcardosods" title="Gabriel Cardoso"><font color=#FF585D>Gabriel Cardoso</font></a>
#
# ---
#
#
# # <font color=#404040><strong>Ora Pois</strong>: Analisando os dados do Airbnb de Lisboal </font>
#
#
# &nbsp;
#
# ## <font color=#404040><strong>Sobre a Airbnb</strong></font>
#
# &nbsp;
#
# <font color=#404040>O <a href=https://www.airbnb.com.br/ title="Airbnb"><font color=#FF585D>Airbnb</font></a> já é considerado um dos maiores mercados de estadia, oferecendo mais de 7 milhões de acomodações e 50 mil atividades personalizadas desenvolvida por anfitriões locais.</font>
#
#
# &nbsp;
#
# > <p align="center"><font color=#FF585D size=4.5>E acredite se quiser, ele <strong>não possui nenhum hotel</strong></font></p>
#
#
# &nbsp;
#
# <font color=#404040>Acessível em 62 idiomas e em mais de 220 países, o Airbnb provome a conexão interpessoal, a comunidade e a confiança no mundo todo.</font>
#
# <font color=#404040>No final de 2018, a Startup fundada 10 anos atrás, já havia <strong>hospedado mais de 300 milhões</strong> de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.</font>
#
# <font color=#404040>Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal <a href=http://insideairbnb.com/get-the-data.html title="Inside Airbnb"><font color=#FF585D>Inside Airbnb</font></a>, é possível encontrar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.</font>
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://raw.githubusercontent.com/gabrielcardosods/data_science/master/images/airbnblogo.png"></center>
#
# <p align="center"<font color="#404040"><strong>Então, neste <i>notebook</i>, iremos analisar os dados referentes à cidade de Fortaleza, ver quais insights podem ser extraídos a partir de dados.</strong></font></p>

# %% [markdown]
# <p><img alt="Minerando" height="30px" src="https://raw.githubusercontent.com/gabrielcardosods/data_science/master/images/miner.png"
# align="left" hspace="10px" vspace="0px"></p>
#
# <h2><font color=#404040><strong>Coleta dos Dados</strong></font></h2>
#
# <font color="404040">Os dados que serão usados estão disponíveis no portal <a href="http://insideairbnb.com/get-the-data.html"><font color=#FF585D>Inside Airbnb</font></a></font>.
#
#
# &nbsp;
#
# <p><img alt="Minerando" height="30px" src="https://raw.githubusercontent.com/gabrielcardosods/data_science/master/images/toolbox.png"
# align="left" hspace="10px" vspace="0px"></p>
#
# <h3><font color=#404040><strong>Kit necessário</strong></font></h3>
#
# Para esta análise exploratória inicial serão necessários apenas
#
#  o **arquivo** com os dados:
# * `listings.csv`: *Summary information and metrics for listings (good for visualisations)*.
#
# E as **bibliotecas** do *python*:
# * `pandas`
# * `matplotlib`
# * `seaborn`

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv('listings.csv', sep=',')

# %% [markdown]
# <h2><font color=#404040><strong>Análise dos Dados</strong></font></h2>
#
#
# Nosso objetivo inicial é conhecer quem são os dados que estamos processando e como estão estruturados.

# %% [markdown]
# <h2><font color=#404040><strong>Dicionário de dados</strong></font></h2>
#
# * `id` - número do id gerado para identificar o imóvel
# * `name` - nome da propriedade do anunciante
# * `host_id` - número do id do proprietário (anfitrião) da propriedade
# * `host_name` - nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review
# * `reviews_per_month`  - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
#
#
# &nbsp;
#
# Antes de realizar qualquer análise, vamos verificar a cara do nosso *dataset*, analisando as 5 primeiras linhas.

# %%
# mostrar as 5 primeiras entradas
df.head()
# Out:
#       id  ... availability_365
# 0   6499  ...              307
# 1  25659  ...              317
# 2  29248  ...              351
# 3  29396  ...              318
# 4  29720  ...              300
#
# [5 rows x 16 columns]

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**
#
# Depois de ter visto como o nosso *dataset* está distribuído, vamos prosseguir e descobrir a quantidade de registros presente no nosso conjunto de dados e identificar o tipo (familía) que cada coluna pertence.
#
# Este *dataset* que baixamos é uma versão resumida do Airbnb. Na mesma página que baixamos o arquivo *listings.csv*, há uma versão [mais completa](http://data.insideairbnb.com/portugal/lisbon/lisbon/2020-04-29/data/listings.csv.gz) chamada *listings.csv.gz*.

# %%
# identificar o volume de dados do DataFrame
info_df = df.shape

print('O dataset é composto por:\nLinhas: {}\nColunas: {}\n'.format(info_df[0], info_df[1]))

# verificar o tipo de cada coluna

display(df.dtypes)
# Out:
# O dataset é composto por:
# Linhas: 24640
# Colunas: 16
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ### **Q2. Qual a porcentagem de valores ausentes no *dataset*?**
#
# Acabamos de ver que o nosso *dataset* é composta de 24.640 linhas e 16 colunas. Existem muitos *insights* ainda a serem descobertos. Então, vamos prosseguir!
#
# Uma informação importante quando estamos lidando com um *dataset* é analisar se há valores faltantes e verificar se essa ausecência impacta os resultados do nosso estudo.
#
# Podemos notar que:
# * As colunas `reviews_per_month` e `last_review` possuem valores faltantes em mais de 16% dos registros

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
round((df.isnull().sum()/df.shape[0]).sort_values(ascending=False)*100, 2)
# Out:
# reviews_per_month                 16.85
# last_review                       16.85
# name                               0.08
# host_name                          0.00
# availability_365                   0.00
# calculated_host_listings_count     0.00
# number_of_reviews                  0.00
# minimum_nights                     0.00
# price                              0.00
# room_type                          0.00
# longitude                          0.00
# latitude                           0.00
# neighbourhood                      0.00
# neighbourhood_group                0.00
# host_id                            0.00
# id                                 0.00
# dtype: float64

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**
#
# Vamos visualizar agora como cada variável do nosso conjunto está distribuida. Para isso, vamos gerar histogramas.

# %%
# plotar o histograma das variáveis numéricas
hist = df.hist(bins=15, figsize=(15,10), color='#FF585D')
hist;

# %% [markdown]
# ### **Q4. Qual a média dos preços de aluguel?**
#
#
# Podemos observar atráves do histograma que existem algumas variáveis sem utilidade. Vamos focar naquelas que podem gerar *insights* interessantes, como por exemplo o preço.
#
# Vamos verificar qual é o preço mais comum entre as estadias em Lisboa. Para isso, utilizaremos as duas medidas de tendência central: a média aritmética e a mediana.

# %%
# ver a média da coluna `price`

price_mean = df.price.mean()
price_median= df.price.median()

print('Usando a média, a maioria das estadias em Lisboa tem preços próximos a $ {:.2f}.\n'.format(price_mean))
print('Agora aplicando a mediana, boa parte das estadias em Lisboa apresentam preços em torno de $ {:.2f}.'.format(price_median))
# Out:
# Usando a média, a maioria das estadias em Lisboa tem preços próximos a $ 110.74.
#
# Agora aplicando a mediana, boa parte das estadias em Lisboa apresentam preços em torno de $ 69.00.

# %% [markdown]
# Comparado os resultados, percebemos que existe uma alta diferença entre o resultado da média e da mediana.
# Esta divergência ocorre por conta da existência de ***outliers*** presentes em nosso conjunto.
#
# Estes *outliers* impactam o resultado gerado pela média já que ela é classificada como uma medida estatística sensível.
#
# Portanto nesse caso, a melhor medida para averir o centro dos nosso conjunto é a mediana e além disso percebemos sua distribuição é positiva.
#
# Vamos plotar novamente o histograma de preço sem a presença deles para visualizarmos o que foi dito!

# %%
df_price = df[df['price'] <= 1500]['price']

plt.hist(x=df_price, color='#FF585D', bins=30)
plt.title('Histrograma do preço das estadias')
plt.xlabel('Preço das estadias')
plt.ylabel('Frequência');

# %% [markdown]
# ### **Q4. Qual a correlação existente entre as variáveis?**
#
# Uma informação interessante para nós agora é se há relação entre as variáveis do conjunto.
#
# Para sanar essa dúvida, vamos utilizar a **Matriz de correlação**

# %%
# criar uma matriz de correlação
corr = df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()
display(corr)

# mostrar a matriz de correlação
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);
# Out:
#                                    price  ...  availability_365
# price                           1.000000  ...          0.000202
# minimum_nights                 -0.011188  ...         -0.017730
# number_of_reviews              -0.067521  ...          0.083130
# reviews_per_month              -0.103551  ...          0.076544
# calculated_host_listings_count -0.019413  ...          0.047716
# availability_365                0.000202  ...          1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# Observando a matriz notamos que há uma relação forte entre `reviews_per_month`e o `number_of_reviews`, porém esta relação não tem utilidade alguma.

# %% [markdown]
# ### **Q5. Qual o tipo de imóvel mais alugado em Lisboa?**
#
# A coluna `room_type` é composta pelos tipos do quartos da estadia. Através da análise podemos verificar que o tipo mais frequente disponível é *Entire home/apt* com quase 72% das estadias.

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df.room_type.value_counts()
# Out:
# Entire home/apt    17892
# Private room        5726
# Hotel room           578
# Shared room          444
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
round(df.room_type.value_counts()/df.shape[0], 3)*100
# Out:
# Entire home/apt    72.6
# Private room       23.2
# Hotel room          2.3
# Shared room         1.8
# Name: room_type, dtype: float64

# %% [markdown]
# ### **Q6. Qual a localidade mais cara em Lisboa?**
#
# Uma boa maneira de descobrir qual a localidade mais cara, ou a mais barata, é utilizando o método do pandas `.groupby`. Vamos então comparar a localidade com base no preço média das estadias.

# %%
# ver preços por bairros, na média
round(df.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10],2)
# Out:
# neighbourhood
# Ramada e Caneas           298.67
# Vermelha                  292.50
# Cardosas                  280.00
# Mina de gua               276.68
# Aveiras de Baixo          269.50
# Ota                       249.00
# Freiria                   220.00
# Benfica                   202.15
# Marvila                   197.78
# So Domingos de Benfica    183.35
# Name: price, dtype: float64

# %%
df.neighbourhood.unique()
# Out:
# array(['Belm', 'Santa Maria Maior', 'Estrela', 'Avenidas Novas', 'Lumiar',
#        'Misericrdia', 'Cascais e Estoril',
#        'S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim',
#        'Alenquer (Santo Estvo e Triana)', 'So Vicente', 'Campolide',
#        'Santo Antnio', 'Barcarena', 'Alvalade', 'Alcabideche',
#        'So Domingos de Benfica', 'Vila Franca de Xira',
#        'Algueiro-Mem Martins', 'Penha de Frana', 'Arroios',
#        'Carcavelos e Parede', 'Colares',
#        'Venda do Pinheiro e Santo Estvo das Gals', 'Carvoeira e Carmes',
#        'Rio de Mouro', 'Alcntara', 'Parque das Naes', 'Campo de Ourique',
#        'Igreja Nova e Cheleiros', 'Areeiro', 'Ericeira', 'Ajuda',
#        'Lourinh e Atalaia', 'Reguengo Grande', 'Mafra',
#        'Cadaval e Pro Moniz',
#        'Algs, Linda-a-Velha e Cruz Quebrada-Dafundo',
#        'Oeiras e S.Julio da Barra, Pao de Arcos e Caxias',
#        'So Joo das Lampas e Terrugem', 'So Pedro da Cadeira', 'Ramalhal',
# ...

# %%
# plotar os imóveis pela latitude-longitude
df.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df['price'], s=8, 
        cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# ### **Q7. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
# ver a média da coluna `minimum_nights``

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Depois de feita uma análise superficial no conjunto de dados do Airbnb, já podemos observar que existem *outliers* presentes em algumas das variáveis.
#
# Também se notou que em algumas localidades há poucos imóveis disponíveis, o que pode distorcer as informações estatísticas de alguns atributos.
#
# Por fim, lembra-se que este dataset é uma versão resumida, ideal apenas para uma abordagem introdutória. Recomenda-se que seja usado, em uma próxima análise exploratória, o conjunto de dados completos, com 106 atributos disponíveis.
